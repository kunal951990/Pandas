# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
import webbrowser

# %%
website= "http://en.wikipedia.org/wiki/NFL_win-loss_records"

# %%
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard(engine='python', sep='\t+')

# %%
nfl_frame
# Out:
#                        Rank
# 0                      Team
# 1                        GP
# 2                       Won
# 3                      Lost
# 4                      Tied
# 5                      Pct.
# 6          First NFL Season
# 7                  Division
# 8                         1
# 9            Dallas Cowboys
# 10                      882
# 11                      502
# 12                      374
# 13                        6
# 14                     .573
# 15                     1960
# 16                 NFC East
# 17                        2
# 18        Green Bay Packers
# 19                    1,336
# 20                      737
# 21                      562
# 22                       37
# 23                     .565
# 24                     1921
# 25                NFC North
# 26                        3
# 27            Chicago Bears
# 28                    1,370
# 29                      749
# ..                      ...
# 32                     .562
# ...

# %%
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
nfl_frame_list = pd.read_html(website,match='Rank',header=0)
nfl_frame = nfl_frame_list[0]

# %%
nfl_frame
# Out:
#     Rank                     Team    GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys   882  502   374     6  0.573
# 1      2        Green Bay Packers  1336  737   562    37  0.565
# 2      3            Chicago Bears  1370  749   579    42  0.562
# 3      4           Miami Dolphins   800  445   351     4  0.559
# 4      5  New England Patriots[b]   884  489   386     9  0.558
# 5      6        Minnesota Vikings   870  470   390    10  0.546
# 6      7         Baltimore Ravens   352  190   161     1  0.541
# 7      8          New York Giants  1305  687   585    33  0.539
# 8      9           Denver Broncos   884  470   404    10  0.537
# 9     10      San Francisco 49ers  1002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1179  614   538    20  0.532
# 11    12          Oakland Raiders   884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]   966  506   453     7  0.527
# 13    14       Kansas City Chiefs   884  457   415    12  0.524
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame2 = pd.DataFrame(nfl_frame, columns = ['Team', 'First NFL Season', 'Team'])

# %%
nfl_frame2
# Out:
#                        Team  First NFL Season                     Team
# 0            Dallas Cowboys              1960           Dallas Cowboys
# 1         Green Bay Packers              1921        Green Bay Packers
# 2             Chicago Bears              1920            Chicago Bears
# 3            Miami Dolphins              1966           Miami Dolphins
# 4   New England Patriots[b]              1960  New England Patriots[b]
# 5         Minnesota Vikings              1961        Minnesota Vikings
# 6          Baltimore Ravens              1996         Baltimore Ravens
# 7           New York Giants              1925          New York Giants
# 8            Denver Broncos              1960           Denver Broncos
# 9       San Francisco 49ers              1950      San Francisco 49ers
# 10      Pittsburgh Steelers              1933      Pittsburgh Steelers
# 11          Oakland Raiders              1960          Oakland Raiders
# ...
