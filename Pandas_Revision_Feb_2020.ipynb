# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\kisku\\Desktop\\data\\New folder\\survey_results_public.csv")

# %%
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# #### To display all columns, we use pd.set_option('display.max_columns',no_of_column)

# %%
pd.set_option('display.max_columns',85)    # pd.set_option('display.max_columns',number) will display all the columns.

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
schema_df = pd.read_csv("C:\\Users\\kisku\\Desktop\\data\\New folder\\survey_results_schema.csv")

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
people = {'Name':['Ram','Shyam','Gopal'],
         'Amount':['20000','30000','40000'],
         'Email':['ram@gmail.com','shyam@yahoo.com','gopal@rediff.com']}

# %%
people['Name']
# Out:
# ['Ram', 'Shyam', 'Gopal']

# %%
pop = pd.DataFrame(people)

# %%
pop
# Out:
#     Name Amount             Email
# 0    Ram  20000     ram@gmail.com
# 1  Shyam  30000   shyam@yahoo.com
# 2  Gopal  40000  gopal@rediff.com

# %%
pop.set_index('Email')  # to set index we use dataframe.set_index('Column_Name',inplace=True)
# Out:
#                    Name Amount
# Email
# ram@gmail.com       Ram  20000
# shyam@yahoo.com   Shyam  30000
# gopal@rediff.com  Gopal  40000

# %%
pop
# Out:
#     Name Amount             Email
# 0    Ram  20000     ram@gmail.com
# 1  Shyam  30000   shyam@yahoo.com
# 2  Gopal  40000  gopal@rediff.com

# %%
pop.set_index('Email',inplace=True)  # to set index we use dataframe.set_index('Column_Name',inplace=True)

# %%
pop
# Out:
#                    Name Amount
# Email
# ram@gmail.com       Ram  20000
# shyam@yahoo.com   Shyam  30000
# gopal@rediff.com  Gopal  40000

# %%
pop.index
# Out:
# Index(['ram@gmail.com', 'shyam@yahoo.com', 'gopal@rediff.com'], dtype='object', name='Email')

# %%
ds = pd.read_csv("C:\\Users\\kisku\\Desktop\\data\\New folder\\survey_results_public.csv", index_col='Respondent')

# %%
ds
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
schema_ds = pd.read_csv("C:\\Users\\kisku\\Desktop\\data\\New folder\\survey_results_schema.csv", index_col= 'Column')
# to fix the index we use attribute index_col='Column_Name'

# %%
schema_ds
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_ds.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_ds.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema_ds.sort_index(inplace=True)  # sorting index by using dataframe.sort_index() and for modifying the dataframe on which sort_index is called, dataframe.sort_index(inplace=True)

# %%
schema_ds
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
pop
# Out:
#                    Name Amount
# Email
# ram@gmail.com       Ram  20000
# shyam@yahoo.com   Shyam  30000
# gopal@rediff.com  Gopal  40000

# %%
pop[pop['Name']=='Ram'] # filtering
# Out:
#               Name Amount
# Email
# ram@gmail.com  Ram  20000

# %%
df[df['LanguageWorkedWith']=='Python']   # filtering with single condition
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 30             31             I am a student who is learning to code       No
# 44             45  I am not primarily a developer, but I write co...      Yes
# 367           369             I am a student who is learning to code      Yes
# 508           510                     I am a developer by profession      Yes
# 648           651                        I code primarily as a hobby      Yes
# 656           659                     I am a developer by profession      Yes
# 725           728                     I am a developer by profession       No
# 821           824             I am a student who is learning to code      Yes
# 1002         1006                     I am a developer by profession      Yes
# 1398         1405  I am not primarily a developer, but I write co...      Yes
# 1448         1455                     I am a developer by profession       No
# ...

# %%
df[(df['LanguageWorkedWith']=='Python') & (df['Gender']=='Woman')] # filtering with two conditions
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 30             31             I am a student who is learning to code       No
# 367           369             I am a student who is learning to code      Yes
# 656           659                     I am a developer by profession      Yes
# 1448         1455                     I am a developer by profession       No
# 1986         1994  I used to be a developer by profession, but no...      Yes
# 4940         4963                     I am a developer by profession       No
# 6022         6047                     I am a developer by profession      Yes
# 7019         7048  I am not primarily a developer, but I write co...      Yes
# 8260         8297                     I am a developer by profession       No
# 9243         9283  I am not primarily a developer, but I write co...       No
# 9395         9435                        I code primarily as a hobby      Yes
# ...

# %%
df[(df['LanguageWorkedWith']=='Python') & (df['Gender']!='Man')] # filtering in dataframe and using two conditions.
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 30             31             I am a student who is learning to code       No
# 367           369             I am a student who is learning to code      Yes
# 656           659                     I am a developer by profession      Yes
# 1448         1455                     I am a developer by profession       No
# 1986         1994  I used to be a developer by profession, but no...      Yes
# 4940         4963                     I am a developer by profession       No
# 6022         6047                     I am a developer by profession      Yes
# 7019         7048  I am not primarily a developer, but I write co...      Yes
# 8260         8297                     I am a developer by profession       No
# 9243         9283  I am not primarily a developer, but I write co...       No
# 9395         9435                        I code primarily as a hobby      Yes
# ...

# %%
df[(df['LanguageWorkedWith']=='Python') & (df['Gender']!='Man')].index   # example of filter and then specifying
# Out:
# Int64Index([   30,   367,   656,  1448,  1986,  4940,  6022,  7019,  8260,
#              9243,  9395,  9410, 10403, 10809, 11169, 11187, 12539, 12633,
#             13260, 15311, 15436, 15865, 16502, 17443, 22826, 23374, 25654,
#             26671, 27223, 27998, 29402, 30709, 31336, 32707, 33502, 34568,
#             37026, 37360, 37982, 39182, 39312, 39646, 39754, 39964, 40435,
#             41592, 42006, 43465, 44652, 45355, 45438, 48054, 49065, 49249,
#             50563, 51291, 51816, 51977, 52997, 53174, 53704, 58897, 58971,
#             59489, 59786, 60191, 61919, 62708, 63806, 64161, 64291, 64606,
#             67101, 68558, 68804, 68860, 69708, 69943, 70085, 70699, 71091,
#             71244, 73049, 73697, 73733, 74218, 74465, 76747, 77424, 78492,
#             78619, 78855, 81387, 81541, 81716, 82456, 84505, 85484, 87116,
#             87959],
#            dtype='int64')

# %%
pop
# Out:
#                    Name Amount
# Email
# ram@gmail.com       Ram  20000
# shyam@yahoo.com   Shyam  30000
# gopal@rediff.com  Gopal  40000

# %%
pop.columns = ['name','amount']   # changing column name.

# %%
pop.rename(columns={'name':'NAME','amount':'AMOUNT'},inplace=True)   # renaming column names by passing dictionary.

# %%
pop
# Out:
#                    NAME AMOUNT
# Email
# ram@gmail.com       Ram  20000
# shyam@yahoo.com   Shyam  30000
# gopal@rediff.com  Gopal  40000

# %%
pop.reset_index(inplace=True) # to get default indexing  .reset()

# %%
pop.loc[:]
# Out:
#               Email   NAME AMOUNT
# 0     ram@gmail.com    Ram  20000
# 1   shyam@yahoo.com  Shyam  30000
# 2  gopal@rediff.com  Gopal  40000

# %%
pop.loc[0] = ['karan@gmail.com','Karan',50000]  # to change the record

# %%
pop
# Out:
#               Email   NAME AMOUNT
# 0   karan@gmail.com  Karan  50000
# 1   shyam@yahoo.com  Shyam  30000
# 2  gopal@rediff.com  Gopal  40000
